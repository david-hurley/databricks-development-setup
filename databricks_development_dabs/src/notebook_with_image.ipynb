# %%
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.randint(0, 10, size=10).tolist()

plt.plot(vals)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Basic Line Plot')
plt.show()
